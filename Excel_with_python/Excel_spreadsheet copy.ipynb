# %%
pip install pandas openpyxl xlrd xlwt xlsxwriter
# Out:
# ...
#                                               0.0/251.4 kB ? eta -:--:--
#      ------------------------------         204.8/251.4 kB 4.1 MB/s eta 0:00:01
#      -------------------------------------- 251.4/251.4 kB 5.1 MB/s eta 0:00:00
# ...
#                                               0.0/96.5 kB ? eta -:--:--
#      ---------------------------------------- 96.5/96.5 kB 5.8 MB/s eta 0:00:00
# ...
#                                               0.0/100.0 kB ? eta -:--:--
#      -------------------------------------- 100.0/100.0 kB 5.6 MB/s eta 0:00:00
# ...
#                                               0.0/159.9 kB ? eta -:--:--
#      ------------------------------------- 159.9/159.9 kB 10.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import openpyxl
import xlrd
import xlwt
import xlsxwriter

print("Libraries installed successfully")
# Out:
# Libraries installed successfully

# %%
import pandas as pd

# Read a single sheet
df = pd.read_excel('excels files/sample.xlsx', sheet_name='Allocation')
print(df.head())
# Out:
#   Ticker    Asset Class                  Sector  \
# 0  GOOGL  Public Equity  Communication Services
# 1   AMZN  Public Equity  Consumer Discretionary
# 2   AAPL  Public Equity  Information Technology
# 3   APTV  Public Equity  Consumer Discretionary
# 4   ASML  Public Equity  Information Technology
#
#                                      Industry        Country  \
# 0                Interactive Media & Services  United States
# 1          Internet & Direct Marketing Retail  United States
# 2  Technology Hardware, Storage & Peripherals  United States
# 3                      Auto Parts & Equipment  United States
# 4                              Semiconductors         Europe
#
#    Current Invested Amount Currency  Unnamed: 7      Unnamed: 8 Unnamed: 9  \
# 0                 636000.0      USD         NaN     Asset Class     Amount
# 1                 746000.0      USD         NaN   Public Equity    4242000
# 2                 380000.0      USD         NaN  Private Equity     850000
# ...

# %%
# Read multiple sheets
sheets = pd.read_excel('excels files/sample.xlsx', sheet_name=['Allocation', 'Holding'])
print(sheets)
# Out:
# {'Allocation':    Ticker     Asset Class                  Sector  \
# 0   GOOGL   Public Equity  Communication Services
# 1    AMZN   Public Equity  Consumer Discretionary
# 2    AAPL   Public Equity  Information Technology
# 3    APTV   Public Equity  Consumer Discretionary
# 4    ASML   Public Equity  Information Technology
# 5     NKE   Public Equity       Consumer Cyclical
# 6    BABA   Public Equity       Consumer Cyclical
# 7     TSM   Public Equity  Information Technology
# 8     TLT    Fixed Income         Government Bond
# 9     HYG    Fixed Income          Corporate Bond
# 10    TIP    Fixed Income         Government Bond
# 11    PSP  Private Equity              Financials
# 12    PEX  Private Equity              Financials
# 13    IYR     Real Estate             Real Estate
# 14    REZ     Real Estate             Real Estate
# 15    NaN             NaN                     NaN
# 16    NaN             NaN                     NaN
# ...

# %%
# Reading .xls file
df_xls = pd.read_excel('excels files/sample.xls')

# Reading .xlsx file
df_xlsx = pd.read_excel('excels files/sample.xlsx')

# %%
# Create a DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'], 'Age': [28, 24, 35, 32]}
df = pd.DataFrame(data)

# Write DataFrame to Excel
df.to_excel('excels files/output.xlsx', index=False)
df
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   24
# 2  Peter   35
# 3  Linda   32

# %%
with pd.ExcelWriter('excels files/output_multi_sheets.xlsx') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
    df.to_excel(writer, sheet_name='Sheet2', index=False)

# %%
# Create a DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'], 'Age': [28, 24, 35, 32]}
df = pd.DataFrame(data)

# Write DataFrame to Excel with formatting
with pd.ExcelWriter('excels files/formatted_output.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
    
    # Get the xlsxwriter workbook and worksheet objects.
    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']
    
    # Add a format.
    format1 = workbook.add_format({'num_format': '0.00'}) 

    # Set the column width and format.
    worksheet.set_column('B:B', 18, format1)

# %%
# Load existing file
df_existing = pd.read_excel('excels files/output.xlsx')

# New data
new_data = {'Name': ['Chris', 'Sarah'], 'Age': [22, 30]}
df_new = pd.DataFrame(new_data)

# Append new data
df_combined = df_existing._append(df_new, ignore_index=True)

# Save to the same file
df_combined.to_excel('excels files/output.xlsx', index=False)

df_combined
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   24
# 2  Peter   35
# 3  Linda   32
# 4  Chris   22
# 5  Sarah   30

# %%
# Load existing file
df = pd.read_excel('excels files/output.xlsx')

# Modify a cell value
df.at[1, 'Age'] = 30

# Save the changes
df.to_excel('excels files/output.xlsx', index=False)

df
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   30
# 2  Peter   35
# 3  Linda   32
# 4  Chris   22
# 5  Sarah   30

# %%
# Load existing file
df = pd.read_excel('excels files/output.xlsx')

# Insert a new column
df['New_Column'] = ['Value1', 'Value2', 'Value3', 'Value4', 'Value5', 'Value6']

# Save the changes
df.to_excel('excels files/output.xlsx', index=False)

# %%
df
# Out:
#     Name  Age New_Column
# 0   John   28     Value1
# 1   Anna   30     Value2
# 2  Peter   35     Value3
# 3  Linda   32     Value4
# 4  Chris   22     Value5
# 5  Sarah   30     Value6

# %%
df.drop(columns=['New_Column'], inplace=True)

# %%
df
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   30
# 2  Peter   35
# 3  Linda   32
# 4  Chris   22
# 5  Sarah   30

# %%
# Create a DataFrame
data = {'Number1': [10, 20, 30], 'Number2': [1, 2, 3]}
df = pd.DataFrame(data)

# Write DataFrame to Excel with formulas
with pd.ExcelWriter('excels files/formulas.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
    
    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']
    
    # Write a formula
    worksheet.write_formula('C2', '=A2+B2')

# %%
df
# Out:
#    Number1  Number2
# 0       10        1
# 1       20        2
# 2       30        3

# %%
# Create a DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'], 'Age': [28, 24, 35, 32]}
df = pd.DataFrame(data)

# Write DataFrame to Excel and add a chart
with pd.ExcelWriter('excels files/charts.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
    
    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']
    
    # Create a chart object.
    chart = workbook.add_chart({'type': 'column'})
    
    # Configure the chart with data series.
    chart.add_series({
        'categories': ['Sheet1', 1, 0, 4, 0],
        'values':     ['Sheet1', 1, 1, 4, 1],
    })
    
    # Insert the chart into the worksheet.
    worksheet.insert_chart('E2', chart)

# %%
# Create a DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'], 'Score': [85, 78, 92, 88]}
df = pd.DataFrame(data)

# Write DataFrame to Excel with conditional formatting
with pd.ExcelWriter('excels files/conditional_formatting.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
    
    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']
    
    # Apply conditional formatting
    worksheet.conditional_format('B2:B5', {'type': '3_color_scale'})

# %%
import pandas as pd

# Load data
df = pd.read_excel('excels files/monthly_report.xlsx')

# Perform some operations
df['Total'] = df['Quantity'] * df['Price']

# Save the updated file
df.to_excel('excels files/updated_report.xlsx', index=False)

df
# Out:
#     Item  Quantity  Price  Total
# 0  Item1        10      5     50
# 1  Item2        20     10    200
# 2  Item3        30     15    450

# %%
try:
    df = pd.read_excel('excels files/non_existent_file.xlsx')
except FileNotFoundError as e:
    print(f"Error: {e}")
# Out:
# Error: [Errno 2] No such file or directory: 'excels files/non_existent_file.xlsx'

# %%
from sqlalchemy import create_engine

# Create an engine
engine = create_engine('sqlite:///my_database.db')

# Read from database
df = pd.read_sql('SELECT * FROM my_table', engine)

# Write to Excel
df.to_excel('excels files/from_database.xlsx', index=False)

df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# OperationalError: no such table: my_table
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Load data from Excel
df = pd.read_excel('excels files/output.xlsx')

# Export to CSV
df.to_csv('excels files/output.csv', index=False)

# Export to JSON
df.to_json('excels files/output.json', orient='records')
