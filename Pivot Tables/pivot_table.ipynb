# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35, 28, 31, 36],
    'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Los Angeles', 'Chicago'],
    'Sales': [200, 150, 100, 300, 250, 200]
}
df = pd.DataFrame(data)

# %%
print(df.head())
# Out:
#       Name  Age         City  Sales
# 0    Alice   25     New York    200
# 1      Bob   30  Los Angeles    150
# 2  Charlie   35      Chicago    100
# 3    Alice   28     New York    300
# 4      Bob   31  Los Angeles    250

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   City    6 non-null      object
#  3   Sales   6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes
# None

# %%
pd.pivot_table(df, values='Sales', index='City', columns='Name', aggfunc='mean', fill_value=0, margins=True, dropna=True, margins_name='Total', observed=False)
# Out:
# Name         Alice    Bob  Charlie  Total
# City
# Chicago        0.0    0.0    150.0  150.0
# Los Angeles    0.0  200.0      0.0  200.0
# New York     250.0    0.0      0.0  250.0
# Total        250.0  200.0    150.0  200.0

# %%
import pandas as pd

# Sample data
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
    'City': ['New York', 'Los Angeles', 'New York', 'Los Angeles'],
    'Sales': [200, 150, 300, 250]
}

df = pd.DataFrame(data)

# Creating a pivot table
pivot = pd.pivot_table(df, values='Sales', index='Date', columns='City', aggfunc='sum')
print(pivot)
# Out:
# City        Los Angeles  New York
# Date
# 2023-01-01          150       200
# 2023-01-02          250       300

# %%
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
    'City': ['New York', 'Los Angeles', 'New York', 'Los Angeles'],
    'Product': ['A', 'B', 'A', 'B'],
    'Sales': [200, 150, 300, 250]
}

df = pd.DataFrame(data)

# Multi-index pivot table
pivot = pd.pivot_table(df, values='Sales', index=['Date', 'City'], columns='Product', aggfunc='sum')
print(pivot)
# Out:
# Product                     A      B
# Date       City
# 2023-01-01 Los Angeles    NaN  150.0
#            New York     200.0    NaN
# 2023-01-02 Los Angeles    NaN  250.0
#            New York     300.0    NaN

# %%
# Using multiple aggregation functions
pivot = pd.pivot_table(df, values='Sales', index='Date', columns='City', aggfunc=[sum, len])
print(pivot)
# Out:
#                    sum                  len
# City       Los Angeles New York Los Angeles New York
# Date
# 2023-01-01         150      200           1        1
# 2023-01-02         250      300           1        1
# <ipython-input-35-02a3510fbd8a>:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot = pd.pivot_table(df, values='Sales', index='Date', columns='City', aggfunc=[sum, len])

# %%
# Filling missing values with 0
pivot = pd.pivot_table(df, values='Sales', index='Date', columns='City', aggfunc='sum', fill_value=0)
print(pivot)
# Out:
# City        Los Angeles  New York
# Date
# 2023-01-01          150       200
# 2023-01-02          250       300

# %%
# Styling the pivot table
pivot.style.format('${:.2f}').background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_3b45d_row0_col0, #T_3b45d_row0_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_3b45d_row1_col0, #T_3b45d_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_3b45d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >City</th>
#       <th id="T_3b45d_level0_col0" class="col_heading level0 col0" >Los Angeles</th>
#       <th id="T_3b45d_level0_col1" class="col_heading level0 col1" >New York</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b45d_level0_row0" class="row_heading level0 row0" >2023-01-01</th>
#       <td id="T_3b45d_row0_col0" class="data row0 col0" >$150.00</td>
#       <td id="T_3b45d_row0_col1" class="data row0 col1" >$200.00</td>
#     </tr>
#     <tr>
#       <th id="T_3b45d_level0_row1" class="row_heading level0 row1" >2023-01-02</th>
#       <td id="T_3b45d_row1_col0" class="data row1 col0" >$250.00</td>
#       <td id="T_3b45d_row1_col1" class="data row1 col1" >$300.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Renaming index and columns
pivot.rename(columns={'New York': 'NY', 'Los Angeles': 'LA'}, inplace=True)
pivot.rename_axis('City', axis='columns', inplace=True)
pivot.rename_axis('Sales Date', axis='index', inplace=True)
print(pivot)
# Out:
# City         LA   NY
# Sales Date
# 2023-01-01  150  200
# 2023-01-02  250  300

# %%
# Adding margins
pivot = pd.pivot_table(df, values='Sales', index='Date', columns='City', aggfunc='sum', margins=True)
print(pivot)
# Out:
# City        Los Angeles  New York  All
# Date
# 2023-01-01          150       200  350
# 2023-01-02          250       300  550
# All                 400       500  900

# %%
# Optimizing memory usage
df['Sales'] = df['Sales'].astype('int32')

# %%
df['Sales']
# Out:
# 0    200
# 1    150
# 2    300
# 3    250
# Name: Sales, dtype: int32

# %%
df
# Out:
#          Date         City Product  Sales
# 0  2023-01-01     New York       A    200
# 1  2023-01-01  Los Angeles       B    150
# 2  2023-01-02     New York       A    300
# 3  2023-01-02  Los Angeles       B    250
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('City').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Product').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='index', y='Sales', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Sales']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Sales')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Sales']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('City')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='City', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Sales')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Sales']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Product')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Product', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Sales')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['City'].value_counts()
#     for x_label, grp in _df_12.groupby('Date')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Date')
# _ = plt.ylabel('City')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Product'].value_counts()
#     for x_label, grp in _df_13.groupby('City')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('City')
# _ = plt.ylabel('Product')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='index', y='Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['City'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='index', y='City', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['Product'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='index', y='Product', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Sales', y='Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1FgxPE9ezBdA3henPj9STJ2bi6AFJQRT-DN9RjhL7XfI#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1FgxPE9ezBdA3henPj9STJ2bi6AFJQRT-DN9RjhL7XfI#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
